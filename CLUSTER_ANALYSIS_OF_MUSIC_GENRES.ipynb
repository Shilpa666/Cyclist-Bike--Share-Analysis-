# %% [markdown]
# <a href="https://colab.research.google.com/github/Shilpa666/Cyclist-Bike--Share-Analysis-/blob/main/CLUSTER_ANALYSIS_OF_MUSIC_GENRES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly as py
import plotly.graph_objs as go

from sklearn.cluster import KMeans

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Data Exploration

# %%
df = pd.read_csv('./Spotify-2000.csv')

df.head()
# Out:
#    Index                   Title             Artist            Top Genre  \
# 0      1                 Sunrise        Norah Jones      adult standards
# 1      2             Black Night        Deep Purple           album rock
# 2      3          Clint Eastwood           Gorillaz  alternative hip hop
# 3      4           The Pretender       Foo Fighters    alternative metal
# 4      5  Waitin' On A Sunny Day  Bruce Springsteen         classic rock
#
#    Year  Beats Per Minute (BPM)  Energy  Danceability  Loudness (dB)  \
# 0  2004                     157      30            53            -14
# 1  2000                     135      79            50            -11
# 2  2001                     168      69            66             -9
# 3  2007                     173      96            43             -4
# 4  2002                     106      82            58             -5
#
#    Liveness  Valence Length (Duration)  Acousticness  Speechiness  Popularity
# ...

# %%
df.shape
# Out:
# (1994, 15)

# %%
df.describe()
# Out:
#              Index         Year  Beats Per Minute (BPM)       Energy  \
# count  1994.000000  1994.000000             1994.000000  1994.000000
# mean    997.500000  1992.992979              120.215647    59.679539
# std     575.762538    16.116048               28.028096    22.154322
# min       1.000000  1956.000000               37.000000     3.000000
# 25%     499.250000  1979.000000               99.000000    42.000000
# 50%     997.500000  1993.000000              119.000000    61.000000
# 75%    1495.750000  2007.000000              136.000000    78.000000
# max    1994.000000  2019.000000              206.000000   100.000000
#
#        Danceability  Loudness (dB)     Liveness      Valence  Acousticness  \
# count   1994.000000    1994.000000  1994.000000  1994.000000   1994.000000
# mean      53.238215      -9.008526    19.012036    49.408726     28.858074
# std       15.351507       3.647876    16.727378    24.858212     29.011986
# ...

# %%
df.columns
# Out:
# Index(['Index', 'Title', 'Artist', 'Top Genre', 'Year',
#        'Beats Per Minute (BPM)', 'Energy', 'Danceability', 'Loudness (dB)',
#        'Liveness', 'Valence', 'Length (Duration)', 'Acousticness',
#        'Speechiness', 'Popularity'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1994 entries, 0 to 1993
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Index                   1994 non-null   int64
#  1   Title                   1994 non-null   object
#  2   Artist                  1994 non-null   object
#  3   Top Genre               1994 non-null   object
#  4   Year                    1994 non-null   int64
#  5   Beats Per Minute (BPM)  1994 non-null   int64
#  6   Energy                  1994 non-null   int64
#  7   Danceability            1994 non-null   int64
#  8   Loudness (dB)           1994 non-null   int64
#  9   Liveness                1994 non-null   int64
#  10  Valence                 1994 non-null   int64
#  11  Length (Duration)       1994 non-null   object
#  12  Acousticness            1994 non-null   int64
#  13  Speechiness             1994 non-null   int64
# ...

# %%
df.dtypes
# Out:
# Index                      int64
# Title                     object
# Artist                    object
# Top Genre                 object
# Year                       int64
# Beats Per Minute (BPM)     int64
# Energy                     int64
# Danceability               int64
# Loudness (dB)              int64
# Liveness                   int64
# Valence                    int64
# Length (Duration)         object
# Acousticness               int64
# Speechiness                int64
# Popularity                 int64
# dtype: object

# %% [markdown]
# Checking for null values

# %%
df.isnull().sum()
# Out:
# Index                     0
# Title                     0
# Artist                    0
# Top Genre                 0
# Year                      0
# Beats Per Minute (BPM)    0
# Energy                    0
# Danceability              0
# Loudness (dB)             0
# Liveness                  0
# Valence                   0
# Length (Duration)         0
# Acousticness              0
# Speechiness               0
# Popularity                0
# dtype: int64

# %% [markdown]
#  Top five genres by Popularity

# %%
df['Top Genre'].value_counts()
# Out:
# album rock           413
# adult standards      123
# dutch pop             88
# alternative rock      86
# dance pop             83
#                     ...
# streektaal             1
# indie anthem-folk      1
# la pop                 1
# ccm                    1
# bebop                  1
# Name: Top Genre, Length: 149, dtype: int64

# %%
polt=df.groupby('Top Genre').agg({'Popularity':'mean'}).sort_values('Popularity',ascending=False).head(5)

# %%
sns.barplot(data=polt,x=polt.index,y='Popularity')
# Out:
# <Axes: xlabel='Top Genre', ylabel='Popularity'>

# %% [markdown]
# Correlation map

# %%
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1)
# Out:
# <Axes: >

# %%
sns.regplot(x=df['Loudness (dB)'],y=df['Energy'])
# Out:
# <Axes: xlabel='Loudness (dB)', ylabel='Energy'>

# %%
sns.regplot(x=df['Beats Per Minute (BPM)'],y=df['Popularity'])
# Out:
# <Axes: xlabel='Beats Per Minute (BPM)', ylabel='Popularity'>

# %%
sns.regplot(x=df['Energy'],y=df['Popularity'])
# Out:
# <Axes: xlabel='Energy', ylabel='Popularity'>

# %% [markdown]
# 2D Clustering based on Popularity and Beats Per Minute (BPM)

# %%
plt.figure(1 , figsize = (15 , 7))
plt.title('Energy v/s Popularity', fontsize = 20)
plt.xlabel('Energy')
plt.ylabel('Popularity')
plt.scatter( x = 'Energy', y = 'Popularity', data = df, s = 100)
plt.show()

# %% [markdown]
# Deciding K value

# %%
X1 = df[['Popularity' ,'Energy']].iloc[: , :].values
inertia = []
for n in range(1 , 15):
    algorithm = (KMeans(n_clusters = n ,init='k-means++', n_init = 10 ,max_iter=300,
                        tol=0.0001,  random_state= 111  , algorithm='elkan') )
    algorithm.fit(X1)
    inertia.append(algorithm.inertia_)

# %%
plt.figure(1 , figsize = (15 ,6))
plt.plot(np.arange(1 , 15) , inertia , 'o')
plt.plot(np.arange(1 , 15) , inertia , '-' , alpha = 0.5)
plt.xlabel('Number of Clusters') , plt.ylabel('Inertia')
plt.show()

# %%
algorithm = (KMeans(n_clusters = 3, init='k-means++', n_init = 10, max_iter=1,
                        tol=0.0001, random_state= 111 , algorithm='elkan'))
algorithm.fit(X1)
labels1 = algorithm.labels_
centroids1 = algorithm.cluster_centers_

# %%
h = 0.02
x_min, x_max = X1[:, 0].min() - 1, X1[:, 0].max() + 1
y_min, y_max = X1[:, 1].min() - 1, X1[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = algorithm.predict(np.c_[xx.ravel(), yy.ravel()])

# %%
plt.figure(1 , figsize = (15 , 7) )
plt.clf()
Z = Z.reshape(xx.shape)
plt.imshow(Z , interpolation='nearest',
           extent=(xx.min(), xx.max(), yy.min(), yy.max()),
           cmap = plt.cm.Pastel2, aspect = 'auto', origin='lower')

plt.scatter( x = 'Energy', y = 'Popularity', data = df, c = labels1, s = 100)
plt.scatter(x = centroids1[: , 0] , y =  centroids1[: , 1] , s = 300 , c = 'red' , alpha = 0.5)
plt.ylabel('Popularity') , plt.xlabel('Energy')
plt.show()

# %%
from sklearn.metrics import silhouette_score
silhouette_score(X1,labels1)
# Out:
# 0.37150520639622214
